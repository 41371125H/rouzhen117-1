# %%
def hello(msg):
  print(msg)
hello('hello')
hello('good morning')
# Out:
# hello
# good morning

# %%
def hello(name,age):
  msg=f'{name} is {age} years old'
  print (msg)

# %%
def a(x,y):
  result=x+y*2
  return result

b=a(1,2)
c=a(2,3)
print (b,c)
# Out:
# 5 8

# %%
def a(x):
  result=0
  while result<10:
    result=result+x
    if result==5:
      return result
  return result
b=a(1)
c=a(2)
print(b,c)
# Out:
# 5 10

# %%
def tf(value):
 return 2 * value - 1
 # 測試這個函數
test_values = [1, 2, 3, 4, 5, 6]
scaled_values = [tf(value) for value in test_values]
print("Original values: ", test_values)
print("Scaled values: ", scaled_values)
# Out:
# Original values:  [1, 2, 3, 4, 5, 6]
# Scaled values:  [1, 3, 5, 7, 9, 11]

# %%
def a(n):
  if n==0 or n==1:
    return 1
  else:
    return n+a(n-1)
print(a(3))
# Out:
# 6

# %%
with open('test.txt','w') as f1:
  f1.write('good morning')

# %%
 import datetime
 print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:56:44.987400
# 2024-09-26

# %%
import pandas as pd
import numpy as np
dates = pd.date_range("20130101", periods=6)
print(dates)
df = pd.DataFrame(np.random.randn(6, 4), index=dates,
columns=list("ABCD"))
print(df)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01 -1.259536  0.835393  1.210872 -0.605570
# 2013-01-02  0.926905  0.894912  1.378972  0.322559
# 2013-01-03 -1.197980  0.465618  1.703223  0.752960
# 2013-01-04  1.092758  0.918940  1.805631  1.152766
# 2013-01-05 -0.111210  0.034215 -1.538058 -1.102772
# 2013-01-06  1.738975  0.001275  1.466113 -0.241381

# %%
df.describe( )
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.164574 -0.143689 -0.757200  0.304829
# std    0.619001  0.871379  0.441014  0.998749
# min   -0.403919 -1.104907 -1.192004 -1.190607
# 25%   -0.259595 -0.618304 -1.024332 -0.077001
# 50%   -0.049019 -0.353601 -0.912510  0.254226
# 75%    0.466548  0.113550 -0.563118  0.748640
# max    1.180785  1.387248 -0.017915  1.785093

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.403919   -0.329679    0.638295   -0.049344    1.180785   -0.048693
# B    1.387248   -0.520677   -0.650846    0.213574   -0.186524   -1.104907
# C   -0.911348   -1.192004   -0.447041   -0.017915   -1.061219   -0.913673
# D   -1.190607    1.785093    0.846691    0.454485   -0.120657    0.053967

# %%
df.iloc[3]
df.iloc[3:5, 0:2]
df.iloc[1:3, :]
df[df > 0]
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.926905  0.894912  1.378972  0.322559
# 2013-01-04  1.092758  0.918940  1.805631  1.152766
# 2013-01-06  1.738975  0.001275  1.466113 -0.241381

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2[df2["E"].isin(["two", "four"])]
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -1.259536 -0.835393 -1.210872 -0.605570
# 2013-01-02 -0.926905 -0.894912 -1.378972 -0.322559
# 2013-01-03 -1.197980 -0.465618 -1.703223 -0.752960
# 2013-01-04 -1.092758 -0.918940 -1.805631 -1.152766
# 2013-01-05 -0.111210 -0.034215 -1.538058 -1.102772
# 2013-01-06 -1.738975 -0.001275 -1.466113 -0.241381

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
df1.dropna( )
df1.fillna(5)
df1.interpolate( )
# Out:
#                    A         B         C         D    E
# 2013-01-01 -1.259536  0.835393  1.210872 -0.605570  1.0
# 2013-01-02  0.926905  0.894912  1.378972  0.322559  1.0
# 2013-01-03 -1.197980  0.465618  1.703223  0.752960  1.0
# 2013-01-04  1.092758  0.918940  1.805631  1.152766  1.0
